# %%
import csv
import json
import csv
import pymongo
from datetime import datetime

csv_file_path = "finalAdjusted.csv"

# Initialize an empty list to store JSON data
json_data = []

# Read CSV file and convert to JSON format
with open(csv_file_path, 'r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        date = row["DateTime"].split(" ")[0]
        timestamp_str = row["DateTime"]
        timestamp_obj = datetime.strptime(timestamp_str, "%Y-%m-%d %H:%M:%S.%f")
        if row["securityId"] == '':
            securityId= None
        else:
            securityId = row["securityId"]

        json_data.append({
            "id": None,
            "businessDate": date,
            "securityId": securityId,
            "symbol": row["StockSymbol"],
            "openPrice": float(row["OpeningPrice"]),
            "highPrice": float(row["HighestPrice"]),
            "lowPrice": float(row["LowestPrice"]),
            "closePrice": float(row["LastTradePrice"]),
            "totalTradedQuantity": int(row["TotalTradedVolume"]),
            "totalTradedValue": None,
            "previousDayClosePrice":None,
            "fiftyTwoWeekHigh": float(row["FiftyTwoWeekHigh"]),
            "fiftyTwoWeekLow": float(row["FiftyTwoWeekLow"]),
            "lastUpdatedTime": row["LastTradeTime"],
            "lastUpdatedPrice": float(row["LastTradePrice"]),
            "totalTrades": int(row["TotalTrades"]),
            "averageTradedPrice": float(row["AveragePrice"]),
            "marketCapitalization": None,
        })

# Create the final JSON structure
final_json = {
    "content": json_data
}

client = pymongo.MongoClient('mongodb+srv://pranavdahal:NW0NR8zXe85nwCYs@cluster0.cqakhhi.mongodb.net/')

db = client['nepse']
todayPrice = db['todayPrice']

data = final_json['content']
print(data)
todayPrice.insert_many(data)

# # Convert the dictionary to a JSON string
# final_json_string = json.dumps(final_json, indent=4)

# # Print or write the JSON string to a file
# print(final_json_string)

# # If you want to write the JSON string to a file
# with open("output.json", "w") as output_file:
#     output_file.write(final_json_string)

print("JSON data has been generated and printed/written.")
# Out:
# [{'id': None, 'businessDate': '2018-03-29', 'securityId': '1999999', 'symbol': 'PRANAV', 'openPrice': 668.61, 'highPrice': 699.71, 'lowPrice': 668.61, 'closePrice': 699.71, 'totalTradedQuantity': 266, 'totalTradedValue': None, 'previousDayClosePrice': None, 'fiftyTwoWeekHigh': 2810.0, 'fiftyTwoWeekLow': 710.0, 'lastUpdatedTime': '14:06:54.0000000', 'lastUpdatedPrice': 699.71, 'totalTrades': 8, 'averageTradedPrice': 1017.96, 'marketCapitalization': None}, {'id': None, 'businessDate': '2018-03-29', 'securityId': '199999', 'symbol': 'DAHAL', 'openPrice': 668.61, 'highPrice': 699.71, 'lowPrice': 668.61, 'closePrice': 699.71, 'totalTradedQuantity': 266, 'totalTradedValue': None, 'previousDayClosePrice': None, 'fiftyTwoWeekHigh': 2810.0, 'fiftyTwoWeekLow': 710.0, 'lastUpdatedTime': '14:06:54.0000000', 'lastUpdatedPrice': 699.71, 'totalTrades': 8, 'averageTradedPrice': 1017.96, 'marketCapitalization': None}]
# JSON data has been generated and printed/written.
